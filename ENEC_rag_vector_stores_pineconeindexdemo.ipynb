# %% [markdown]
# <a href="https://colab.research.google.com/github/khaledaldhaheri91-maker/khaled1/blob/main/ENEC_rag_vector_stores_pineconeindexdemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pinecone Vector Store

# %% [markdown]
# If you're opening this Notebook on colab, you will probably need to install LlamaIndex 🦙.

# %%
# %pip install llama-index llama-index-vector-stores-pinecone
# Out:
# Requirement already satisfied: llama-index in /usr/local/lib/python3.12/dist-packages (0.14.10)
# Requirement already satisfied: llama-index-vector-stores-pinecone in /usr/local/lib/python3.12/dist-packages (0.7.1)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.5.3)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.10 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.14.10)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.5.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.9.4)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.6.11)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.5.5)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index) (0.5.1)
# Requirement already satisfied: nltk>3.8.1 in /usr/local/lib/python3.12/dist-packages (from llama-index) (3.9.1)
# Requirement already satisfied: pinecone<8.0.0,>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-pinecone) (7.3.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (3.13.2)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (2.2.0)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (2025.3.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (2.11.5)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (2.0.2)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (4.5.1)
# Requirement already satisfied: pydantic>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (2.12.3)
# Requirement already satisfied: pyyaml>=6.0.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (6.0.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (2.32.4)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.10->llama-index) (2.0.44)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (0.12.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (4.15.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.10->llama-index) (1.17.3)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (2.9.0)
# Requirement already satisfied: llama-cloud==0.1.35 in /usr/local/lib/python3.12/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from llama-cloud==0.1.35->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.11.12)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.13.5)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.2)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (6.4.2)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>3.8.1->llama-index) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>3.8.1->llama-index) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>3.8.1->llama-index) (2025.11.3)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=7.0.0->llama-index-vector-stores-pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=7.0.0->llama-index-vector-stores-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=7.0.0->llama-index-vector-stores-pinecone) (2.9.0.post0)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.12/dist-packages (from pinecone<8.0.0,>=7.0.0->llama-index-vector-stores-pinecone) (2.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.10->llama-index) (1.22.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (1.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (3.1.6)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.8)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.10->llama-index) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.10->llama-index) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->llama-index-core<0.15.0,>=0.14.10->llama-index) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.15.0,>=0.14.10->llama-index) (0.16.0)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.10->llama-index) (0.4.2)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in /usr/local/lib/python3.12/dist-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: packaging<25.0,>=24.2 in /usr/local/lib/python3.12/dist-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone<8.0.0,>=7.0.0->llama-index-vector-stores-pinecone) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=7.0.0->llama-index-vector-stores-pinecone) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (3.4.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.10->llama-index) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.10->llama-index) (3.26.1)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.2.1)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.15.0,>=0.14.10->llama-index) (3.0.3)

# %%
import logging
import sys
import os

logging.basicConfig(stream=sys.stdout, level=logging.INFO)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %% [markdown]
# #### Creating a Pinecone Index

# %%
from pinecone import Pinecone, ServerlessSpec

# %%
import openai
from google.colab import userdata

# Retrieve the OpenAI API key from Google Colab secrets
openai.api_key = userdata.get('openai')

if openai.api_key:
    os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
#PUT Tyour api key

from google.colab import userdata


api_key = userdata.get('PINECONE_API_KEY')

if api_key:
    os.environ["PINECONE_API_KEY"] = api_key


pc = Pinecone(api_key=api_key)

# %%
api_key
# Out:
# 'pcsk_4AiajQ_DVhXhPDBPKco8Ba1ifB4f7QjHF3SxivC4MMHcdNa5xEyWk49ubVGNFEhSttYPEY'

# %%
# dimensions are for text-embedding-ada-002

pc.create_index(
    name="quickstart",
    dimension=1536,
    metric="euclidean",
    spec=ServerlessSpec(cloud="aws", region="us-east-1"),
)
# Out:
# {
#     "name": "quickstart",
#     "metric": "euclidean",
#     "host": "quickstart-mb6dg4l.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 1536,
#     "deletion_protection": "disabled",
#     "tags": null
# }

# %%
pinecone_index = pc.Index("quickstart")

# %% [markdown]
# #### Load documents, build the PineconeVectorStore and VectorStoreIndex

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.vector_stores.pinecone import PineconeVectorStore
from IPython.display import Markdown, display

# %% [markdown]
# Download Data

# %%
# load documents
documents = SimpleDirectoryReader("./data").load_data()

# %%
documents
# Out:
# [Document(id_='e64f498b-cbd4-4c0c-b29b-c964e3ae3e31', embedding=None, metadata={'page_label': '1', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='SOP: Troubleshooting Overheated Boiler Feed Pump \n(Pump P-201) \nDocument Number: SOP-OPS-MAINT-2025-07 \nRevision: 1.0 \nAuthor: J. Smith (Maintenance Engineer) \nApproved: A. Khan (Plant Manager) – 2025-12-10 \nPlant/Unit: Sunrise Thermal Power Plant – Unit 3 \nEffective Date: 15-Dec-2025 \nPurpose and Scope \nThis document establishes the standard procedure for troubleshooting an overheated \nindustrial pump (Boiler Feed Pump P-201) in the thermal power plant. It outlines the \npurpose, safety precautions, step-by-step actions, and diagnostics to identify and \nresolve an overheating condition. The scope covers Pump P-201 (feedwater pump) in Unit \n3 and applies to operations and maintenance personnel. It addresses recognizing \noverheating symptoms, immediate safety measures, root cause investigation, corrective \nactions, and safe restart of the pump. This SOP ensures consistent response to pump \noverheating incidents to minimize downtime and equipment damage[1][2]. \nEquipment Details \nEquipment ID: Pump P-201 (Boiler Feedwater Pump) \nType: Horizontal multistage centrifugal pump (ring-section design) for high-pressure \nfeedwater service. \nService: Feeds condensed water (feedwater) to the boiler economizer at ~180 °C. \nDesigned for continuous operation in a thermal power cycle. \nDriver: 3.3 kV Electric Motor (2000 kW) with direct coupling to pump shaft. \nOperating Parameters: ~300 m³/hr at 15 MPa discharge (rated), supplying feedwater to \nmaintain drum level. Suction from Deaerator at ~0.5 MPa and 120 °C. \nConstruction: Eight-stage pump with between-bearing design; journal and thrust bearings \nare oil-lubricated with an external oil cooler. A minimum flow recirculation line returns \nwater to the dearator to prevent low-flow overheating. The pump is installed on a grout-\nfilled baseplate with a flexible coupling to the motor, and is instrumented with temperature \nsensors on bearings, a vibration monitor, and pressure/flow transmitters. \nSymptoms of Overheating \nWhen Pump P-201 is overheating, one or more of the following symptoms may be \nobserved: ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='8d3d0273-968e-410b-8108-34bd2837a68b', embedding=None, metadata={'page_label': '2', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='• High Bearing Temperature: Bearing metal temperature surpasses normal limits \n(typically normal <70\u202f°C, alarm ~85\u202f°C)[3]. Control room alarms (e.g. “Pump P-201 \nBearing Temp High”) may trigger. Prolonged operation beyond ≈ 82–104\u202f°C can risk \nseal failure, shaft distortion, and lubricant breakdown[2]. \n• Pump Casing Hot to Touch: The pump casing and bearing housing feel abnormally \nhot. Infrared thermometer readings show temperature well above ambient. An \noverheated pump casing (especially if no flow) indicates internal friction or pump \nrunning dry/low-flow conditions[4][5]. \n• Unusual Noise or Vibration: Overheating bearings may be accompanied by a \ngrinding or howling noise and increased vibration levels[6]. Cavitation (from vapor \nlock or low NPSH) can cause rattling noises and also generates hot spots in the \npump[7]. \n• Automatic Trip/Shutdown: The pump may trip on thermal protection. Many \npumps have built-in safety: e.g. a bearing temperature high-high trip around 95–\n100\u202f°C or a motor winding temperature trip. If the pump driver is a motor, the \nmotor’s thermal relay might trip due to overheating, stopping the pump. \n• Visible Smoke or Odor: In extreme cases, overheated oil in bearings can produce a \nburning smell. Oil may appear dark or burnt (blackened) if it has overheated[8]. \nPaint on the pump or bearing brackets might discolor. Any smoke at the pump or \nmotor is a severe warning sign. \nImmediate Safety Actions \nSafety is paramount. At the first sign of pump overheating, take these immediate actions \nto ensure personnel and equipment safety: \n1. Notify and Assess: Inform the Control Room and shift supervisor. If the pump \nhasn’t already tripped, evaluate if it’s safe to keep running briefly or if an emergency \nshutdown is needed. Often, a boiler feed pump has a standby; be prepared to start \nthe standby pump and transfer load if possible, to allow P-201 to be taken offline \nsafely. \n2. Reduce Load (If Running): If the process allows, slowly reduce the pump’s load \nor flow to lessen internal heating[9]. Do not abruptly stop a pump supplying an \noperating boiler unless the standby is running, to avoid upsetting boiler water \nsupply. If the pump is not critically needed (e.g. unit can be tripped or backed \ndown), commence a controlled shutdown. \n3. Emergency Shutdown: If the pump shows signs of imminent failure (rapidly rising \ntemperature, smoke, or vibration), trip the pump immediately. Use the local \nEmergency Stop or instruct the control room to stop the motor. Verify the pump \nhas stopped rotation. Close the discharge valve quickly after trip (if not automatic) \nto prevent backflow, and crack open the pump vent or a top vent valve to avoid \nvacuum collapse as it cools. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='5b3b68e7-60e2-4758-a960-81661fa98d3c', embedding=None, metadata={'page_label': '3', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='4. Lockout/Tagout (LOTO): Apply full energy isolation. Electrically isolate the pump \ndriver by opening the motor breaker and applying a padlock and tag on it (per LOTO \nprocedure). Isolate fluid energy by closing the suction and discharge isolation \nvalves. Attach locks and warning tags on valves and switches, indicating \n“Equipment Under Maintenance – Do Not Operate”[10]. Relieve any trapped \npressure safely: open drain valves to depressurize the pump casing into a suitable \ncontainer or drain (caution: hot water!). Verify zero energy state – no pressure, no \nflow, and motor cannot start[11]. \n5. Personal Protective Equipment: Don appropriate PPE before approaching the \npump[12]. At minimum: insulated gloves (to handle hot surfaces), face shield and \nsafety goggles (hot water/steam splash risk), arc-rated coveralls (if electrical \nhazards), hard hat, and steel-toe boots. Ensure no skin is exposed to potential \nhigh-temperature spray. \n6. Area Safety and Cool-Down: Barricade the area if necessary to keep personnel at a \nsafe distance. Post signage like “HOT SURFACE” on the pump. Allow the pump to \ncool naturally. Do not touch or open it until temperature falls to a safe level \n(typically below 40\u202f°C on the surface). Use fans or ventilation to dissipate heat if in \nan enclosed space, but do not apply cold water on hot casings (risk of cracking). \n7. Fire Watch: If any smoke or fire was observed, have a fire extinguisher on hand and \na fire watch in place. Overheated oil or insulation could ignite. Confirm no fire risk \nbefore proceeding. \n8. Hazard Assessment: Before troubleshooting, perform a hazard assessment of the \narea[13]. Ensure no slip hazards (e.g. oil that may have leaked – clean it up), verify \nadequate lighting, and confirm that any adjacent equipment is stable. \nDo NOT proceed with further investigation or disassembly until the pump is fully isolated, \nlocked out, depressurized, and cooled. Once these immediate safety measures are in \nplace, troubleshooting can begin. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='656e1531-12ce-42a4-823d-5bbeb21808c8', embedding=None, metadata={'page_label': '4', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text=' \nBefore troubleshooting, ensure the pump is fully isolated and all safety protocols are \nfollowed. Lock out the power and valves, and wear appropriate PPE while the equipment \ncools. Trained technicians must verify zero energy (electrical and pressure) prior to hands-\non inspection[10][12]. \nStep-by-Step Troubleshooting Procedure \nFollow this systematic procedure to identify the cause of the overheating and correct it. All \nsteps should be logged in the work order or maintenance log, including measurements and \nfindings at each stage. \n1. Verify Overheat Condition: Confirm that the pump indeed experienced overheating \nand it’s not a false alarm. Check the bearing temperature gauges or electronic \nreadings for P-201 in the control system. Use an infrared thermometer to \nindependently measure the bearing housing and pump casing temperature[14]. \nNote the highest temperature observed and compare with allowable limits (e.g., \n>85\u202f°C which is above normal alarm)[2]. Also verify if any sensor malfunction could \nbe a factor (e.g., a faulty temperature sensor giving false reading[15]). If possible, \ninspect the temperature element wiring and calibration dates. \n2. Review Operating Status: Determine how the pump was operating at the time of \noverheating. Gather data from the DCS or pump log: flow rate, discharge pressure, \nsuction pressure, motor amps, and any recent transients. An overheating event \ncan be exacerbated by operation outside normal range – for example, running the \npump at very low flow (dead-heading) or below minimum flow can cause the \npump to overheat due to internal fluid friction[5]. Conversely, running at excessive \nflow (overload) can overheat the motor and bearings[16]. Note if the pump was in \nrecirculation mode, or if the minimum flow recirc valve was stuck closed. If the \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='324abbc5-a697-40bf-a2d1-82c90d02041c', embedding=None, metadata={'page_label': '5', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='feedwater tank (deaerator) level or pressure was abnormal (causing suction issues), \nrecord that as well. \n3. Switch to Standby (if available): If not already done, start the standby feed pump \n(P-202 if installed) to take over feedwater supply. Transfer the boiler feedwater load \ngradually to the standby pump. Once the standby is up to speed and carrying load, \nshut down the overheated pump (if it hasn’t tripped already). This ensures you can \ntroubleshoot without impacting unit operation. Note: Always adhere to changeover \nprocedures – open the discharge of standby pump, close the discharge of P-201 \nafter current equalization, etc., to avoid water hammer or loss of feed. \n4. Isolation and Drain (re-check): Re-verify that Pump P-201 is electrically and \nhydraulically isolated per the Immediate Safety Actions section. Double-check \nthat tags are in place and that there is no residual pressure. Open the pump casing \nvent valve at the top to ensure no pressure builds up due to residual heat. Open a \ndrain valve at the bottom of the pump casing to collect a sample of fluid (caution: it \nmay still be hot water). This fluid sample can be checked for signs of overheating \n(e.g., if water flashed to steam or any oil presence due to seal leak). Then close \ndrains/vents once pressure is relieved. \n5. External Visual Inspection: Perform a thorough external check of the pump \nassembly: \n6. Lubrication Oil Level: Look at the sight glass on the bearing oil reservoir. The oil \nlevel should be at the marked midpoint. If it’s low or empty, that’s a major cause of \noverheating (inadequate lubrication)[17]. Top up the oil to proper level only after \ncooling, and investigate any oil leakage that caused the loss[17]. \n7. Lubrication Oil Condition: Observe oil color through the sight glass or dipstick. \nDark, blackened, or cloudy oil indicates thermal breakdown or contamination. \nSmell the oil – a burnt odor means it has likely overheated and lost lubricity[8]. Plan \nto drain and replace degraded oil after internal inspection. \n8. Cooling Water Lines: Check the bearing oil cooler or cooling jacket lines. Ensure \nthe cooling water supply valve is open and water is flowing. Carefully touch (or use \nIR) on the inlet vs. outlet piping of the oil cooler – a significant temperature \ndifference should be felt if cooling is working. Little to no difference could mean a \nblocked cooler or no flow[18]. Look for any closed valves or clogged strainers in \nthe cooling circuit and open/clean them as needed[18]. \n9. Pump and Motor Coupling: Inspect the coupling for signs of misalignment or \ndamage. Look for rubber element debris (if a flexible coupling), cracked coupling \nbolts, or shifted coupling hubs. Any misalignment can cause excessive bearing \nloading and heat[19]. If the coupling guard is removed, check alignment with a \nstraightedge initially; final alignment will be measured later. \n10. General Area: Check for any oil sprayed around (could indicate a high-pressure oil \nleak from a seal or gasket). Notice any discoloration on the pump casing or motor \n(bluing of metal can indicate overheating). Also verify if the pump’s mechanical ...
#  Document(id_='cacc64f0-04cf-4cff-8094-2287a36146ca', embedding=None, metadata={'page_label': '6', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='11. Check Bearing Lubrication System: If Pump P-201 has an external lube oil system \n(oil pump, filters, cooler), inspect it in detail: \n12. Oil Pump & Pressure: Ensure the lube oil pump (if applicable, sometimes shaft-\ndriven or electric auxiliary pump) is operational. Check the lube oil pressure gauge; \na low reading might indicate the pump failed or a clogged filter. Normal lube oil \npressure should be as per OEM spec (e.g., ~2–3 bar). If zero, that explains the \noverheating (no oil flow). \n13. Oil Filters: Isolate and open the oil filter housing (after ensuring no pressure) to see \nif it’s clogged. A clogged filter can starve bearings of oil. Replace or clean filters as \nneeded. \n14. Oil Cooler: If not already, open any bypass valves and flush the oil cooler. Remove \ncooler end-caps (if design allows) to inspect for scaling or blockage. Clean the \ncooler tubes. Restore cooling water flow and verify no blockage. \n15. After any interventions, refill oil to the correct level with the proper grade (use OEM-\nspecified oil, e.g. ISO VG46 turbine oil). Do not reuse old overheated oil. \n16. Detailed Bearing Inspection: Once the pump is sufficiently cool, consider \ninspecting the bearings themselves: \n17. Remove the bearing housing covers (journal and thrust bearing housings). This may \nrequire unbolting and carefully lifting the covers. Examine the bearing surfaces for \ndiscoloration (a dark brown or black streak indicates overheating), wiping, or metal \nsmear. Overheated babbitt bearings may show babbitt melting or wiping. Rolling-\nelement bearings may show blueing of races or rollers if overheated. If such \ndamage is present, the bearings will need replacement. \n18. Check bearing clearances (with a feeler gauge or by shaft lift test) if possible, to see \nif they are within spec. Overheating can either cause clearance to tighten (thermal \nexpansion) or excessive wear (increasing clearance). \n19. Collect an oil sample (if not already) and consider sending it for analysis – high \nmetal content or varnish would confirm internal wear and overheating[20]. \n20. Shaft and Rotor: Try to rotate the pump shaft by hand (with coupling disconnected, \nusing a turning wrench). It should turn smoothly. Any binding or rubbing sensation \ncould indicate internal contact (e.g., between impeller and casing or wear rings). If \ninternal rubbing is suspected due to thermal expansion, note that as a possible \ncause[21]. \n21. Internal Pump Inspection (if required): If external and bearing inspections have \nnot identified a clear cause, you may need to open the pump casing for internal \ninspection (this is a more involved process requiring pump outage and new \ngaskets/seals): \n22. Drain the pump completely. Unbolt the appropriate casing sections as per the \npump’s maintenance manual (multistage pumps often have through-bolts and \ncasing split rings). \n23. Inspect impellers and diffusers for signs of cavitation (pitted surfaces) or rubbing \n(shiny contact marks where clearance should exist). Cavitation is a common cause ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_templat ...
#  Document(id_='70ef7817-2b70-4658-baf0-f162ab32c54b', embedding=None, metadata={'page_label': '7', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='of overheating and damage – it occurs if NPSH available is too low, causing vapor \nbubbles that collapse and generate heat[22][23]. If you find cavitation damage, \nlikely the pump was starved of NPSH or run at too high temperature on suction. \n24. Check wear ring clearances and balance drum (if any) for tight spots or scoring. \nThermal distortion can cause internal parts to rub. \n25. Look for any foreign object or debris in the pump that could have partially blocked \nflow (though unlikely in feedwater line with strainers, but worth a check). A partially \nblocked suction strainer can cause both cavitation and reduced flow, leading to \noverheating[23]. \n26. After inspection, if damage is found (e.g., impeller wear, seized bearing, etc.), plan \nfor repair or replacement of those parts. Document all findings with photos if \npossible. \n27. Check Alignment & Drive Train: Using precision tools, measure the pump-motor \nalignment. Employ a dial indicator or laser alignment tool on the coupling. Check \nboth offset and angular alignment. Misalignment beyond tolerance (typically \n>0.05 mm for high-speed machinery) can cause bearing stress and overheating[19]. \nIf misaligned, schedule a proper alignment of the motor to pump before restart. \nAlso inspect the baseplate, grouting, and hold-down bolts – a loose foundation can \nlead to vibration and misalignment over time. Tighten any loose bolts (coupling or \nbase). \n28. Review System Conditions: Concurrently, evaluate if systemic issues \ncontributed: Was the feedwater temperature unusually high (e.g., deaerator \nmalfunction leading to higher-than-design suction temp)? High suction temperature \ncan reduce cooling margin and contribute to pump overheating[24]. Ensure the \ndearator is operating at the correct pressure and temperature. Check if the pump \nwas operating continuously without rotation – continuous operation without regular \nswap can accumulate heat (pumps are often alternated to allow cooling)[25]. If no \nrotation schedule was in place, this might be a contributing factor. \n29. Determine Root Cause: Summarize the findings from steps 5–10. Likely root \ncauses of the overheating should become clear. Common findings might include: \nlow oil level, oil cooler blockage, failed bearing, misalignment, cavitation due to \nsuction issues, or running the pump outside its recommended range. It’s possible \nmultiple factors coincided. Identify all that apply. For each root cause identified, \nplan the corrective action (see Root Cause Diagnostics below for typical \ncauses/remedies). If any cause is still not clear, consider consulting the pump OEM \nor a specialist, especially if internal damage is puzzling. \n30. Corrective Actions: Implement repairs and corrections based on the root cause: \no Replace damaged bearings with new ones (or an entire bearing cartridge if \napplicable). Ensure new bearings are installed per OEM procedure, with \nproper clearances and lubrication. \no Fix the lubrication issues: repair leaks, refill with correct oil, replace filters, \nand ensure the cooling system is functional (open valves, clean coolers). \nAfter refilling oil, vent the oil system of  ...
#  Document(id_='706d1e38-0f77-46db-bafd-c4968b0293dd', embedding=None, metadata={'page_label': '8', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='o If misalignment was found, re-align the pump and motor. Use laser \nalignment tools for precision and secure all mounting bolts afterward. \no For cavitation issues, address the upstream cause: ensure suction strainers \nare clean, the dearator pressure/level are stable, and check that any \nminimum flow recirculation valve is operating so the pump never runs at \n<30% design flow[5]. If the recirculation system was faulty (e.g., a closed \nminimum flow valve), repair or adjust it. \no Replace any worn internal parts (impellers, wear rings, mechanical seal, \netc.) as needed before reassembly. \no Documentation: Document all parts replaced and adjustments made. If the \npump required major overhaul, note it in the equipment history. Also \ndocument the cause for future reference (e.g., “Oil cooler 70% blocked with \nscale – cleaned” or “Found bearing wiped due to oil starvation – replaced \nand fixed leak at seal”). \n31. Pre-Startup Check: Before restarting the pump, perform an inspection to verify all \nsteps are completed: All components are reassembled correctly, oil is at proper \nlevel, cooling water is flowing, coupling is reinstalled and aligned, all tools and rags \nare removed from the area, and all LOTO tags are still in place (we will remove \nthem right before restart). Fill out the inspection Checklist in the next section to \nensure nothing is missed. \n \nDuring troubleshooting, carefully inspect gauges, oil levels, and cooling lines for \nanomalies. Systematically check each potential cause of overheating – from lubrication to \nalignment – and record the findings[26][18]. In the image, a technician examines pump \npressure gauges as part of the diagnostic process. \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='7cc5a480-c47a-42f3-b9f3-1fc13d49e6b3', embedding=None, metadata={'page_label': '9', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Root Cause Diagnostics \nBased on the troubleshooting findings, categorize the root cause of the overheating. \nCommon root causes for an overheated pump in a power plant and their diagnostic \nindicators include: \n• Inadequate Lubrication: Low oil level or poor oil quality leads to insufficient \nlubrication, causing bearing metal-to-metal contact and heat[17][27]. Indicators: \nLow sight-glass reading; burnt oil smell; bearing damage observed. Remedy: \nRestore oil to proper level, fix leaks, use correct oil grade, and replace bearings if \ndamaged. Implement regular oil level checks and scheduled oil changes. \n• Cooling System Failure: Blocked or reduced cooling flow to the oil cooler or \nbearing housing causes temperatures to rise[28]. Indicators: Little temperature \ndrop across cooler; fouling in cooling water passages; high oil temperature. \nRemedy: Clean/flush the oil cooler and cooling lines[18], ensure valves are open \nand water quality is good. Consider installing filters or water treatment if scaling is \nrecurrent. \n• Misalignment or Mechanical Friction: Misaligned pump and driver shafts cause \nextra load on bearings and seals, generating heat[19][29]. Internal rubbing (e.g., due \nto thermal expansion or misassembly) can also overheat the pump[21]. Indicators: \nCoupling wear patterns, high vibration, uneven bearing wear. Remedy: Realign the \npump and motor to within tolerance; verify proper thermal expansion procedures \n(warm up pump if needed, allow sliding foot if applicable). Ensure internal \nclearances and alignment pins are per OEM spec during reassembly. \n• Cavitation / Suction Issues: Cavitation occurs if Net Positive Suction Head \n(NPSH) available is too low or feedwater temperature is too high, causing vapor \nbubbles that collapse and generate local heat[7][22]. Also, low flow operation \n(pump running with discharge closed or <30% flow) causes continuous \nrecirculation of hot water inside the pump[5]. Both result in overheating of fluid and \npump. Indicators: Noise (gravel-like or popping sounds), pitted impeller surfaces, \npossibly oscillating discharge pressure. Remedy: Fix suction conditions – maintain \ndearator pressure/level, clean suction strainers[23], and ensure minimum flow line \nis functioning. Avoid operating pump below the minimum flow; if load is low, keep \nrecirculation open or use auto-recirculation valve. \n• Overloading / Operating Beyond Design: Pushing the pump beyond its design \npoint (excess flow or head) or running at full load continuously can overheat the \nmotor and bearings[16][30]. Indicators: Motor current above rated, motor casing \nvery hot, frequent over-current trips, or discharge pressure/flow higher than spec. \nRemedy: Throttle flow to keep pump within its performance curve. If process \ndemands have changed, consider a pump with proper sizing. Ensure safety devices \n(like thermal overloads and flow limiters) are set correctly. \n• Bearing Wear or Failure: A bearing nearing end-of-life (fatigued or contaminated) \ncan run hot even if lubrication is ok, due to increased friction. Indicator: Vibration ', path=None, url=None, mimetype=None), image_resource=None, audi ...
#  Document(id_='9a9e8c77-3e69-4ae8-973f-7dca74c2852e', embedding=None, metadata={'page_label': '10', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='trending upward over time, metal in oil sample, a wobbly shaft or unusual shaft \nmovement. Remedy: Replace bearings at scheduled intervals; investigate any \nbearing that fails prematurely for underlying cause (misalignment, contamination, \netc.). \n• Continuous Operation without Rest: Pump P-201 might have overheated simply \ndue to lack of rotation – running non-stop for extended periods can cause gradual \nheat soak, especially if its standby was never used[25]. Even if within design, \ncontinuous running can wear out oil and components. Remedy: Implement a pump \nrotation schedule (e.g., alternate pumps weekly or monthly)[25] so each pump can \ncool down and undergo maintenance. Ensure oil is changed at recommended \nintervals to avoid degradation. \n• External Environmental Factors: Less common in a controlled power plant \nenvironment, but high ambient temperature or poor ventilation around the pump \ncan impede heat dissipation[31]. For example, if the pump room ventilation failed, \nheat could accumulate. Also, check for any external heat sources near the pump. \nRemedy: Restore room ventilation fans, remove any heat barriers around pump, \nand in extreme cases consider adding a fan or cooling unit for the pump area. \n• Instrumentation Issues: In some cases, the “overheating” might have been a false \nreading from a bad sensor. If no evidence of actual overheating is found, suspect \nthe instrumentation. Remedy: Calibrate or replace faulty temperature sensors, and \nverify the trip settings. \nEach cause above may contribute to the overheating. It’s crucial to address all \ncontributing factors, not just one. For instance, if misalignment and low oil were both \nfound, both issues must be resolved. Reference relevant OEM manuals for tolerance and \nrecommended practices for each fix. Document the root cause analysis in the report and \nupdate the preventive maintenance plan to avoid recurrence (e.g., schedule cooler \ncleaning, alignment checks, etc.). \nSupporting Info: Overheating in pumps is often multifactorial. Industry guidelines (e.g., \nNFPA 20 for fire pumps) note that bearing temps beyond ~82–104 °C are unsafe[2]. Main \ncauses identified in industry case studies include lubrication failures, blocked cooling \npathways, rotor misalignment, cavitation from suction issues, and overloading \nconditions[32] – all of which have been considered in the above analysis. \nInspection Checklist – Overheated Pump P-201 \nAfter completing repairs or adjustments, use the following inspection checklist to ensure \nall necessary items have been addressed and the pump is ready for a safe restart. Each \ncheckpoint should be reviewed and marked off by the responsible engineer or technician: \nInspection Item Acceptable Condition / Criteria \nStatus \n(✔/✘) Remarks \nLOTO Verification All energy sources isolated  e.g., Breaker ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='62e980f9-3312-48a7-a7cb-4ea08c0dd446', embedding=None, metadata={'page_label': '11', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Inspection Item Acceptable Condition / Criteria \nStatus \n(✔/✘) Remarks \n(electrical, hydraulic). tagged, valves \nlocked. \nPump Casing Cool Casing temperature < 40\u202f°C (safe to \ntouch). \n (Use IR gun to \nconfirm). \nOil Level (Bearing \nHousing) \nOil at midpoint of sight glass; no \nvisible leaks[17]. \n (Refilled with ___ \noil grade). \nOil Condition Clean, amber color; no burnt smell \nor turbidity. \n (Oil changed on \nmm/dd/yy). \nOil Pressure (if \napplicable) \n> 2 bar during priming (when pump \nrunning). \n (Measured ___ bar \nat idle). \nCooling Water \nFlow \nCooling water valves open; cooler \ninlet vs outlet warm/cool to \ntouch[18]. \n (Inlet °C / Outlet \n°C). \nBearing \nTemperature \nNormal range 50–70\u202f°C during \noperation[3]; Alarm set ~85\u202f°C. \n (Verify sensor \nreading). \nBearing \nReplacement \nBearings inspected/replaced if \nneeded; clearances OK. \n (New DE/NDE \nbearings \ninstalled?). \nCoupling \nAlignment \nAlignment within 0.05 mm (shim \nadjusted as needed)[19]. \n (Laser alignment \nreport attached). \nCoupling Hardware Coupling bolts tight; elastomer \nelements in good condition. \n (Replaced spider \nelement). \nInternal Inspection Impellers, wear rings, seal in good \ncondition (no rubbing/cavitation \ndamage). \n (Impeller #3 \nreplaced? Y/N). \nSuction Strainer Strainer/basket clean; no debris or \nblockage[23]. \n (Cleaned on \nmm/dd/yy). \nMechanical Seal Seal not leaking; flush/quench lines \n(if any) flowing. \n (Seal replaced? \nY/N). \nBolting & Supports All pump and base bolts torqued; \nsupport clamps secure. \n (Baseplate grout \nintact). \nInstrumentation Temp and vibration sensors \ncalibrated; alarm/trip setpoints \nverified. \n (Calibrated on \nmm/dd/yy). \nStandby \nEquipment \nStandby pump in auto or ready; no \nissues after swap. \n (P-202 returned to \nstandby). \nDocumentation Work order updated; cause and fix  (Report # filed in ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='a1c14c00-c7fd-427f-8832-dcdd60c2af2a', embedding=None, metadata={'page_label': '12', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Inspection Item Acceptable Condition / Criteria \nStatus \n(✔/✘) Remarks \ndocumented; crew sign-off done. CMMS). \nInstructions: For each item, enter a check ✔ if okay or ✘ if not, and add any remarks or \ncorrective actions taken. All items must be ✔ (acceptable) before removing LOTO and \nrestarting Pump P-201. \nRestart Procedure After Repair \nOnce the pump has been inspected and all issues rectified, follow this controlled restart \nprocedure to safely return Pump P-201 to service: \n1. Pre-Start Briefing: Conduct a brief with Operations and Maintenance personnel. \nReview the work done and ensure everyone is aware of the restart plan. Confirm \nthat it’s safe to restart and all team members are clear of the pump area. \n2. Remove Lockouts/Tagouts: The responsible person (maintenance lead) should \nremove the LOTO devices in coordination with the Control Room. Restore power \nsupply to the motor (close breaker) only when instructed, and crack open (partially \nopen) the suction and discharge isolation valves. Ensure the discharge valve is \ninitially mostly closed – do not start the pump on a wide-open discharge valve[33], \nas this can cause a sudden load and “jerk” the system. \n3. Prime and Vent: If the pump was drained or opened, ensure it is fully refilled with \nwater (prime the pump). Open the vent valve on top of the pump casing and fill the \npump either by gravity from the dearator or using a manual filling pump until water \ncomes out of the vent without air. Close the vent. Verify suction valve is fully open \nand suction pressure is normal (deaerator pressure stable). \n4. Cooling & Lube Startup: Start any auxiliary systems first: turn on the cooling water \nflow to the bearings/oil cooler and the lube oil pump (if a separate lube pump exists) \nto establish lubrication before the main pump starts. Verify oil pressure is in range \nand cooling water is flowing. \n5. Bump Check (Rotation): Engage the motor briefly (bump start) to verify the rotation \ndirection is correct (especially if motor leads were disconnected during work). The \npump should rotate in the correct direction (check arrow on casing). Also listen for \nany unusual sounds on this bump. Then stop. If rotation is correct and no \nimmediate issues, proceed. \n6. Start Pump: Start the pump either locally or from the control room per standard \noperating procedures. The pump will come up to speed (for motor-driven, this is \nquick; for steam turbine-driven, follow the warm-up and rolling procedure as \napplicable). Monitor the pump closely during startup. Keep the discharge valve \n~5–10% open initially to allow a minimum flow out (prevent dead-head) but still \nimpose backpressure so the pump isn’t at full load instantly. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='0235499c-5d36-4c32-80c7-3e84b48986fb', embedding=None, metadata={'page_label': '13', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='7. Gradually Load Pump: Once at full speed and stable, slowly open the discharge \nvalve to allow the pump to ramp up to the desired flow/pressure. Do this in \ncoordination with the control room to smoothly transfer feedwater flow from the \nstandby pump (if applicable) or to meet boiler demand. Avoid any rapid flow \nchanges to prevent water hammer. \n8. Monitor Conditions: As the pump reaches normal operating conditions, closely \nmonitor all parameters: bearing temperatures, oil pressure, cooling water \ntemperatures, pump discharge pressure/flow, motor amps, and vibration readings. \nInitially, check bearing temperature every 5 minutes; it should rise slowly and \nstabilize within normal range (e.g., if it was 25\u202f°C ambient, it might stabilize around \n60\u202f°C)[3]. Vibration should remain below alarm (typically <5 mm/s). Listen for any \nabnormal noise (no rattling or grinding should be present). \n9. Leak Check: Inspect all around the pump for leaks as it runs: look at mechanical \nseal (should be no excessive dripping, slight weep could be normal if it’s a packed \ngland), check all flanges and drains. Tighten any packing gland slightly if needed (if \nit’s packing type seal) to stop a steady drip – but do not over-tighten. \n10. Normal Operation: When the pump is fully on-line and stable, notify the control \nroom. The pump can now carry the feedwater load. If this pump was a standby now \nreplacing a failed pump, ensure the system is adjusted accordingly. If both pumps \nwill run in parallel for a time, coordinate their outputs to desired levels. \n11. Post-Start Monitoring: For at least the first hour of operation, have maintenance \npersonnel periodically (every 15 minutes) check the pump’s temperature and other \nvital signs. Ensure the bearing temperature stays well below alarm. Any trending \nupward could indicate an unresolved issue – be prepared to take action if \nsomething isn’t right. \n12. Remove Temporary Controls: Remove any tags or signs that were placed around \nthe pump area indicating it was under maintenance once fully satisfied the pump is \nrunning okay. (However, do keep any “Caution Hot” signs if surfaces are still above \n50\u202f°C). \n13. Documentation and Handover: Formally hand over the pump to Operations. \nDocument the restart date/time and the conditions in the maintenance log. Also \nschedule a follow-up inspection after 24 hours of runtime to re-check bolt \ntightness, oil level, etc. Finally, close the work order with detailed notes on the \ncause and fix. If any Management of Change (MOC) or engineering follow-up is \nrequired (e.g., updating a procedure or design change like adding a bearing \ntemperature sensor), note that for action. \nReminder: Never start or stop the pump with the discharge valve fully open, to avoid water \nhammer and mechanical stress[33]. Starting against a closed (or slightly open) discharge \nensures a smoother ramp-up and prevents sudden jerk loads on the pump and driver, \nwhich can damage bearings and internal components[33]. Always follow the OEM start-up \nguidelines specific to Pump P-201. ', path=None, url=None, mimetype=None), image_resource=None, audio_reso ...
#  Document(id_='ec975915-8495-4330-ba27-3c9605962d0f', embedding=None, metadata={'page_label': '14', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Common Causes and Historical Notes \nOverheating issues with Pump P-201 have occurred in the past. Understanding these \nhistorical cases can help prevent future recurrences. Below are some common causes of \npast overheating incidents and notes from our plant’s history: \n• June 2024 Incident: Pump P-201 tripped on high bearing temperature. Investigation \nfound the lube oil cooler was partially blocked with sediment. Cooling water flow \nwas only ~50%. The reduced heat removal caused gradual temperature rise over a \nshift. The bearing metal temp reached 95\u202f°C triggering a trip. Action: The cooler was \nchemically cleaned and a cooling water filtration system was installed to prevent \nblockage. After this fix, normal bearing temps dropped to ~60\u202f°C under full load. \nThis incident reinforced the importance of regular cooler maintenance. \n• December 2024 Incident: After an overhaul, P-201 experienced overheating and \nhigh vibration on restart. It did not trip, but temperatures were ~10\u202f°C above normal \nand rising. We shut it down as a precaution. Root cause was misalignment – the \npump and motor were not precisely aligned during re-installation. This caused \nexcessive coupling strain and hot bearings. Action: Performed laser alignment \n(found angular misalignment of 0.3 mm at coupling). Post-alignment, the vibration \nand temperature returned to normal. Lesson learned: always perform and verify \nalignment after maintenance. \n• Continuous Operation Issue (General): It was noted in 2023 that Pump P-201 ran \nfor 14 months continuously without rotation, because the standby pump P-202 was \nout of service for overhaul. The extended run led to gradual oil degradation and a \nminor increase in bearing temperature over time. While no trip occurred, the \nbearing temps were ~5\u202f°C higher than when pumps are swapped regularly. Action: \nWe now adhere to a pump changeover schedule – swapping P-201 and P-202 \nmonthly[25]. This allows each pump to cool, and lets maintenance check oil and \ncomponents. Since implementing rotation, bearing temperatures have remained \nconsistently within range. \n• OEM Advisory (2025): The pump manufacturer (ABC Pumps Co.) issued a tech \nbulletin advising to check the minimum flow recirculation orifice for clogging. A \npartially clogged recirc line can reduce bypass flow at low loads, potentially causing \npump overheating due to low-flow operation. We inspected our recirculation line \nand found some scaling. Action: In the next outage, we plan to clean or replace the \nminimum flow orifice and add it to the maintenance checklist. \n• Common Causes Summary: Overall, our experience matches industry guidance: \nmost overheating cases trace back to cooling/lubrication issues, flow extremes, \nor mechanical setup problems[32][34]. By addressing oil quality, keeping cooling \nwater clean, operating within design parameters, and ensuring proper installation, \nwe have significantly reduced overheating occurrences. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='d6ea1e61-43c6-42ee-bc03-5da327a10d43', embedding=None, metadata={'page_label': '15', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='These historical notes should be shared with new engineers and included in training. They \nhighlight why adhering to this SOP and performing regular preventative maintenance (oil \nchanges, cooler flushes, alignment checks, etc.) is critical. \nSafety and Compliance Reminders \nWorking on high-pressure, high-temperature feed pumps involves significant hazards. \nAlways keep these safety and compliance points in mind: \n• Lockout/Tagout: Never bypass or shortcut the LOTO process. Before maintenance, \nall energy sources must be isolated and locked/tagged[10]. Verify isolation each \ntime (try to start the motor with the breaker open to confirm zero energy). This is not \nonly plant policy but also an OSHA requirement for hazardous energy control. \n• Personal Safety: Wear appropriate PPE at all times and be aware of hot surfaces. \nUse insulated tools/gloves on parts that might be hot. If you must work near a \nrunning pump (for inspections), wear hearing protection and stay clear of rotating \nparts (ensure guards are in place). Do not wear loose clothing or jewelry that could \nget caught. \n• Pressure Hazard: Treat any pressurized section with caution. Even after shutdown, \nwait and open drains slowly, as hot water under pressure can cause violent flash \nsteam. Stand to the side of valves/flanges when cracking them open. Ensure relief \npaths are working (like thermal relief valves on isolated sections). \n• Environmental and Regulatory Compliance: Dispose of any waste oil, oily rags, \nused filters, and damaged parts according to environmental regulations. Document \nthe disposal per the plant’s waste management plan. Any release of feedwater or oil \nshould be reported and cleaned up to prevent slips or environmental harm. \n• Follow OEM Guidelines: This SOP complements the OEM manual – always cross-\nreference the pump manufacturer’s recommendations for limits and procedures. \nFor example, OEM may specify maximum casing heat-up rates, specific lubrication \ngrades, or unique restart steps. Ensure compliance with those to maintain warranty \nand integrity. \n• Recordkeeping: It’s crucial to log all maintenance activities in the Computerized \nMaintenance Management System (CMMS) or logbook. Accurate records support \nreliability analysis and compliance audits. Note the date, findings, parts replaced, \nclearances measured, and persons involved. Also log the bearing temperature \ntrends and vibration readings after the event for future reference. \n• Training and Authorization: Only qualified personnel should perform this \ntroubleshooting. Electrical work (isolating motor, etc.) must be done by authorized \nelectricians, and mechanical work by trained millwrights or engineers. Ensure \neveryone has read this SOP and related documents. Conduct drills or reviews of \npump trip response periodically. \n• Compliance Standards: Adhere to relevant standards such as OSHA 1910 for \ngeneral industry safety, and any power industry regulations. For example, NFPA ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c3bc865f-f753-40ac-a11e-981ad6cb6121', embedding=None, metadata={'page_label': '16', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='standards may not directly apply to feed pumps (they apply to fire pumps), but their \nguidelines on temperature limits can be a helpful reference[2]. Company \nengineering standards for rotating equipment should be followed. If an incident \noccurs, it may need to be reported as per regulatory requirements (e.g., if there was \na reportable release or if safety interlocks failed). Always aim for not just \ncompliance but a safety-first culture. \nBy keeping safety at the forefront and following this procedure, maintenance staff can \ntroubleshoot and restore the pump without incident, and ensure reliable and safe \noperation in the power plant. \nAppendix \nA. Instrumentation Alarm/Trip Setpoints (Pump P-201) \n(For reference – actual setpoints as per Instrumentation Dept.) \nParameter High Alarm \nHigh-High \nTrip Notes \nPump Bearing \nMetal Temperature \n85\u202f°C \n(alarm) \n95\u202f°C (trip) Normal ~50–70\u202f°C[3]. Trip based on \nOEM limit ~100\u202f°C[2]. \nLube Oil \nTemperature \n(outlet) \n60\u202f°C 70\u202f°C At oil cooler outlet. High temp may \nindicate cooling issues. \nLube Oil Pressure 1.5 bar (low \nalarm) \n1.0 bar (low \ntrip) \nMeasured at bearing header. Trips \npump on loss of oil pressure. \nPump Casing Drain \nTemperature \n120\u202f°C \n(alarm) \n– (no trip) (If > alarm, indicates possible flash or \nlow flow heating). \nPump Vibration \n(Overall) \n8 mm/s \nRMS \n(alarm) \n12 mm/s \nRMS (trip) \nPer ISO 10816 for this class of \nmachine. \nMotor Winding \nTemperature \n130\u202f°C \n(alarm) \n140\u202f°C (trip) Motor thermal limit (if motor-driven). \nMotor Bearing \nTemperature \n90\u202f°C \n(alarm) \n100\u202f°C (trip) Motor has its own bearings; similar \nlimits as pump. \nSuction Pressure 0.3 MPa \n(low alarm) \n– Low suction can cause cavitation \nalarm. (No trip, but an interlock may \nprevent start if too low). \nDischarge Pressure 14 MPa (low \nalarm) \n16.5 MPa \n(high alarm) \nAlarm if outside normal range \n(indicative of off-curves operation). \nNote: These setpoints are configured in the plant DCS for Pump P-201. Alarm alerts \noperators to take action, Trip will automatically shut down the pump to protect it. Values ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='39a57aac-6a79-489d-a7f0-239588088bac', embedding=None, metadata={'page_label': '17', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='are based on manufacturer’s recommendations and industry practices (bearing temps per \nOEM, aligned with NFPA 20 guidance of ~82–104\u202f°C max[2]). Always refer to the latest \ninstrument datasheets for any updates to these values. \nB. Contact Information \nFor further assistance or to report an incident involving Pump P-201, use the following \ncontact list: \n• Maintenance Lead – Mechanical: John Doe – Phone: +971-55-123-4567, Email: \njohn.doe@sunrisepower.ae \n• Operations Shift Supervisor (Unit 3): Maryam Al Mansoori – Radio: Channel 3, \nPhone: +971-55-234-5678 \n• Instrumentation Engineer: Ahmed Rahim – Ext: 4431, Email: \nahmed.rahim@sunrisepower.ae \n• Maintenance Manager: Li Wei – Ext: 4400, Office: Bldg 5 Room 12 \n• Safety Officer: Priya Patel – Ext: 4015, to be notified in case of any safety incident or \nif permit conditions need review. \n• Pump OEM Support (ABC Pumps Co.): 24/7 Hotline: +1-800-ABC-PUMP (have \npump serial number ready when calling). Local Rep: Gopal Srinivasan – Email: \ngopal.srinivasan@abc-co.com. \nKeep this contact list posted in the control room and maintenance workshop. In an \nemergency (e.g., fire, severe injury), always call the main emergency number (Dial 999 \nfrom plant phone or as per site protocol) before contacting individuals. \n \nRevision History: \n- Rev. 1.0 – 15/12/2025: Initial issue of troubleshooting guide for overheated pump P-201 \n(Author: J. Smith). Approved by Plant Manager A. Khan. \n- Rev. 0.0 – 01/12/2025: Draft created and reviewed by Maintenance and Operations (not \nreleased). \nReferences & Related Documents: \n- Pump P-201 OEM Manual – ABC Pumps Document #BF-P201-O&M, Rev. 2019. \n- Plant Maintenance Procedure ENG-MECH-012: “Rotating Equipment Alignment \nStandard”. \n- HSE Procedure HSE-LOTO-001: “Lockout/Tagout – Control of Hazardous Energy”. \n- Incident Report IR-2024-06: “Investigation of P-201 Overheating on 01-June-2024”. \n- [35]91FirePump – “How to Handle Fire Pump Overheating Problems”, Sec.1, 2025 – for \ngeneral temperature guidelines and causes. \n- [36][37]PowerPlantCalculations – “Boiler Feed Pump Troubleshooting Guide”, 2025 – on \nhigh bearing temperature causes (low oil, cooling). \n- [34][5]PowerPlantCalculations – “BFP Pump Overheating Causes”, 2025 – guidance on ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='18552584-c65e-418b-91ea-db1911c3861f', embedding=None, metadata={'page_label': '18', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='operation at low flow and high flow affecting pump temperature. \n- [38]EmpoweringPumps – “Bearings Run Hot – Troubleshooting”, 2020 – on misalignment \nand lubrication checks for hot bearings. \n- [10][12]MPO Cincinnati – “Industrial Pump Maintenance Checklist”, 2025 – Pre-\nmaintenance safety (LOTO, PPE). \n(End of SOP) \n \n[1] [4] [6] [16] [31] Troubleshooting Guide: How to Prevent A Pump Overheating? \nhttps://www.streampumps.com/product-qa/pump-overheating-240604.html \n[2] [7] [8] [9] [14] [20] [22] [27] [28] [29] [30] [32] [35] How to Handle Fire Pump Overheating \nProblems  \nhttps://www.91firepump.com/media/industry-news/how-to-handle-fire-pump-\noverheating-problems.html \n[3] [5] [15] [17] [18] [21] [23] [24] [25] [33] [34] [36] [37] Power plant and calculations: 12-\ntroubleshooting guide for Boiler Feed Pumps (BFP) \nhttps://www.powerplantandcalculations.com/2025/03/12-troubleshooting-guide-for-\nBoiler-feed-pumps-BFP.html \n[10] [11] [12] [13] Industrial Pump Maintenance Checklist (Free PDF Download) \nhttps://www.mpofcinci.com/blog/industrial-pump-maintenance-checklist/ \n[19] [26] [38] Centrifugal Pump Minute-Troubleshooting: Bearings Run Hot - Empowering \nPumps and Equipment \nhttps://empoweringpumps.com/psg-centrifugal-pump-minute-troubleshooting-bearings-\nrun-hot/ ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %% [markdown]
# The previous error occurred because the variable `pinecone_index` was used before it was defined. To fix this, I have combined the code that defines `pinecone_index` and the code that uses it into a single cell.

# %%
# Initialize Pinecone index
pinecone_index = pc.Index("quickstart")

# initialize without metadata filter
from llama_index.core import StorageContext

vector_store = PineconeVectorStore(pinecone_index=pinecone_index)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex.from_documents(
    documents, storage_context=storage_context
)

# %% [markdown]
# #### Query Index
#
# May take a minute or so for the index to be ready!

# %%
# set Logging to DEBUG for more detailed outputs
import time

query_engine = index.as_query_engine()
start_time = time.time()
response = query_engine.query("what is this document about")
display(Markdown(f"<b>{response}</b>"))

# End timer and print duration
end_time = time.time()
print(f"\nExecution Time: {end_time - start_time:.2f} seconds")
# Out:
# <b>This document outlines the standard procedure for troubleshooting an overheated industrial pump, specifically the Boiler Feed Pump P-201 in a thermal power plant. It covers the purpose, safety precautions, step-by-step actions, and diagnostics to identify and resolve an overheating condition in the pump. The scope includes recognizing overheating symptoms, immediate safety measures, root cause investigation, corrective actions, and safe restart procedures to minimize downtime and equipment damage.</b>
# Execution Time: 2.12 seconds

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>This document outlines the standard procedure for troubleshooting an overheated industrial pump, specifically the Boiler Feed Pump P-201 in a thermal power plant. It covers the purpose, safety precautions, step-by-step actions, and diagnostics to identify and resolve an overheating condition in the pump. The scope includes recognizing overheating symptoms, immediate safety measures, root cause investigation, corrective actions, and safe restart procedures to minimize downtime and equipment damage.</b>

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (5.50.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.118.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.14.8)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
import os
import logging
import sys
import gradio as gr
from IPython.display import Markdown, display

from pinecone import Pinecone, ServerlessSpec
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, StorageContext, Settings
from llama_index.vector_stores.pinecone import PineconeVectorStore
from llama_index.llms.openai import OpenAI

# --- Initialize Pinecone ---

index_name = "quickstart"
dimension = 1536

# Delete index if exists (optional: mirrors original behavior)
if index_name in [idx["name"] for idx in pc.list_indexes()]:
    pc.delete_index(index_name)

from llama_index.llms.openai import OpenAI
Settings.llm = OpenAI(model = "gpt-5.2-2025-12-11" , temperature=0)


# Create Pinecone index
pc.create_index(
    name=index_name,
    dimension=dimension,
    metric="euclidean",
    spec=ServerlessSpec(cloud="aws", region="us-east-1"),
)

pinecone_index = pc.Index(index_name)

# --- Load Data ---
# Create folders & download a sample doc (kept same logic, fixed subfolder creation)

documents = SimpleDirectoryReader("./data").load_data()

# --- Create Index ---
vector_store = PineconeVectorStore(pinecone_index=pinecone_index)
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex.from_documents(documents, storage_context=storage_context)

# --- System Prompt (polite + answer-from-document constraint) ---
SYSTEM_PROMPT = """You are a power plant maintenance assistant.

Help troubleshoot an overheated Boiler Feed Pump (P-201).

Safety first: LOTO, depressurize, cool down.

Check common causes: oil, cooling, bearings, alignment, cavitation, low/high flow.

Give clear, step-by-step actions.

Recommend safe restart only after issues are fixed."
"""

# --- Query Engine ---
query_engine = index.as_query_engine()

def query_doc(user_question: str):
    if not user_question or not user_question.strip():
        return "Please enter a question."
    full_query = f"""{SYSTEM_PROMPT}

User question:
{user_question.strip()}
"""
    try:
        response = query_engine.query(full_query)
        text = str(response).strip()
        # Gentle post-processing to keep it brief/polite
        return text if text else "I couldn’t find that in the document."
    except Exception as e:
        return f"Error: {str(e)}"

# --- Gradio UI (Professional look with logo, centered title) ---
# Use the raw GitHub URL for proper image rendering.
LOGO_URL = "https://raw.githubusercontent.com/khaledaldhaheri91-maker/khaled1/main/ENEC%20logo.png"

CUSTOM_CSS = """
.gradio-container { font-family: Inter, ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, 'Helvetica Neue', Arial; }
.header-wrap {
    display: grid;
    grid-template-columns: 120px 1fr 120px;
    align-items: center;
    gap: 12px;
    padding: 12px 0 8px;
    border-bottom: 1px solid #eaeaea;
}
.header-logo { display:flex; align-items:center; justify-content:flex-start; }
.header-logo img { height: 48px; object-fit: contain; }
.header-title { text-align:center; }
.header-title h1 {
    margin: 0; font-weight: 700; font-size: 1.5rem; line-height: 1.2;
}
.header-spacer { height: 1px; }
.section { padding-top: 8px; }
.footer-note { text-align:center; font-size: 12px; color:#667085; padding: 8px 0 0; }
label.svelte-1ipelgc, .label-wrap label { font-weight: 600; }
"""

with gr.Blocks(css=CUSTOM_CSS, title="Insurance Document QA (LlamaIndex + Pinecone)") as demo:
    # Header with logo (left) and centered title
    with gr.Row(elem_classes="header-wrap"):
        with gr.Column(scale=0, elem_classes="header-logo"):
            gr.HTML(f'<img src="{LOGO_URL}" alt="ENEC" />')
        with gr.Column(scale=1, elem_classes="header-title"):
            gr.HTML("<h1>Insurance QA</h1>")
        with gr.Column(scale=0):
            gr.HTML("")  # right-side spacer

    gr.Markdown(
        "Ask questions based on the Insurance Document "
        "**Answers come only from the document**. If not found, I’ll say so."
    )

    with gr.Group(elem_classes="section"):
        inp = gr.Textbox(
            label="Your question",
            placeholder="e.g., Ask in Insurance Question?",
            lines=2,
        )
        btn = gr.Button("Submit", variant="primary")
        out = gr.Textbox(label="Answer", lines=8)

    btn.click(fn=query_doc, inputs=inp, outputs=out)
    inp.submit(fn=query_doc, inputs=inp, outputs=out)

    gr.Markdown('<div class="footer-note">LlamaIndex + Pinecone • Demo</div>')

demo.launch()

# %% [markdown]
# Replicate the Deplpyment hugging face
# https://huggingface.co/spaces/decodingdatascience/ddsinsurance1
# openai key

# %%
documents
# Out:
# [Document(id_='35b1fe53-64ad-4058-bd6b-843e317903ce', embedding=None, metadata={'page_label': '1', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='SOP: Troubleshooting Overheated Boiler Feed Pump \n(Pump P-201) \nDocument Number: SOP-OPS-MAINT-2025-07 \nRevision: 1.0 \nAuthor: J. Smith (Maintenance Engineer) \nApproved: A. Khan (Plant Manager) – 2025-12-10 \nPlant/Unit: Sunrise Thermal Power Plant – Unit 3 \nEffective Date: 15-Dec-2025 \nPurpose and Scope \nThis document establishes the standard procedure for troubleshooting an overheated \nindustrial pump (Boiler Feed Pump P-201) in the thermal power plant. It outlines the \npurpose, safety precautions, step-by-step actions, and diagnostics to identify and \nresolve an overheating condition. The scope covers Pump P-201 (feedwater pump) in Unit \n3 and applies to operations and maintenance personnel. It addresses recognizing \noverheating symptoms, immediate safety measures, root cause investigation, corrective \nactions, and safe restart of the pump. This SOP ensures consistent response to pump \noverheating incidents to minimize downtime and equipment damage[1][2]. \nEquipment Details \nEquipment ID: Pump P-201 (Boiler Feedwater Pump) \nType: Horizontal multistage centrifugal pump (ring-section design) for high-pressure \nfeedwater service. \nService: Feeds condensed water (feedwater) to the boiler economizer at ~180 °C. \nDesigned for continuous operation in a thermal power cycle. \nDriver: 3.3 kV Electric Motor (2000 kW) with direct coupling to pump shaft. \nOperating Parameters: ~300 m³/hr at 15 MPa discharge (rated), supplying feedwater to \nmaintain drum level. Suction from Deaerator at ~0.5 MPa and 120 °C. \nConstruction: Eight-stage pump with between-bearing design; journal and thrust bearings \nare oil-lubricated with an external oil cooler. A minimum flow recirculation line returns \nwater to the dearator to prevent low-flow overheating. The pump is installed on a grout-\nfilled baseplate with a flexible coupling to the motor, and is instrumented with temperature \nsensors on bearings, a vibration monitor, and pressure/flow transmitters. \nSymptoms of Overheating \nWhen Pump P-201 is overheating, one or more of the following symptoms may be \nobserved: ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='c1d6384f-d94b-4a6c-9349-db5f3e9bde90', embedding=None, metadata={'page_label': '2', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='• High Bearing Temperature: Bearing metal temperature surpasses normal limits \n(typically normal <70\u202f°C, alarm ~85\u202f°C)[3]. Control room alarms (e.g. “Pump P-201 \nBearing Temp High”) may trigger. Prolonged operation beyond ≈ 82–104\u202f°C can risk \nseal failure, shaft distortion, and lubricant breakdown[2]. \n• Pump Casing Hot to Touch: The pump casing and bearing housing feel abnormally \nhot. Infrared thermometer readings show temperature well above ambient. An \noverheated pump casing (especially if no flow) indicates internal friction or pump \nrunning dry/low-flow conditions[4][5]. \n• Unusual Noise or Vibration: Overheating bearings may be accompanied by a \ngrinding or howling noise and increased vibration levels[6]. Cavitation (from vapor \nlock or low NPSH) can cause rattling noises and also generates hot spots in the \npump[7]. \n• Automatic Trip/Shutdown: The pump may trip on thermal protection. Many \npumps have built-in safety: e.g. a bearing temperature high-high trip around 95–\n100\u202f°C or a motor winding temperature trip. If the pump driver is a motor, the \nmotor’s thermal relay might trip due to overheating, stopping the pump. \n• Visible Smoke or Odor: In extreme cases, overheated oil in bearings can produce a \nburning smell. Oil may appear dark or burnt (blackened) if it has overheated[8]. \nPaint on the pump or bearing brackets might discolor. Any smoke at the pump or \nmotor is a severe warning sign. \nImmediate Safety Actions \nSafety is paramount. At the first sign of pump overheating, take these immediate actions \nto ensure personnel and equipment safety: \n1. Notify and Assess: Inform the Control Room and shift supervisor. If the pump \nhasn’t already tripped, evaluate if it’s safe to keep running briefly or if an emergency \nshutdown is needed. Often, a boiler feed pump has a standby; be prepared to start \nthe standby pump and transfer load if possible, to allow P-201 to be taken offline \nsafely. \n2. Reduce Load (If Running): If the process allows, slowly reduce the pump’s load \nor flow to lessen internal heating[9]. Do not abruptly stop a pump supplying an \noperating boiler unless the standby is running, to avoid upsetting boiler water \nsupply. If the pump is not critically needed (e.g. unit can be tripped or backed \ndown), commence a controlled shutdown. \n3. Emergency Shutdown: If the pump shows signs of imminent failure (rapidly rising \ntemperature, smoke, or vibration), trip the pump immediately. Use the local \nEmergency Stop or instruct the control room to stop the motor. Verify the pump \nhas stopped rotation. Close the discharge valve quickly after trip (if not automatic) \nto prevent backflow, and crack open the pump vent or a top vent valve to avoid \nvacuum collapse as it cools. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='cd8489e2-cdb7-48bb-9b05-803b1fa22a8f', embedding=None, metadata={'page_label': '3', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='4. Lockout/Tagout (LOTO): Apply full energy isolation. Electrically isolate the pump \ndriver by opening the motor breaker and applying a padlock and tag on it (per LOTO \nprocedure). Isolate fluid energy by closing the suction and discharge isolation \nvalves. Attach locks and warning tags on valves and switches, indicating \n“Equipment Under Maintenance – Do Not Operate”[10]. Relieve any trapped \npressure safely: open drain valves to depressurize the pump casing into a suitable \ncontainer or drain (caution: hot water!). Verify zero energy state – no pressure, no \nflow, and motor cannot start[11]. \n5. Personal Protective Equipment: Don appropriate PPE before approaching the \npump[12]. At minimum: insulated gloves (to handle hot surfaces), face shield and \nsafety goggles (hot water/steam splash risk), arc-rated coveralls (if electrical \nhazards), hard hat, and steel-toe boots. Ensure no skin is exposed to potential \nhigh-temperature spray. \n6. Area Safety and Cool-Down: Barricade the area if necessary to keep personnel at a \nsafe distance. Post signage like “HOT SURFACE” on the pump. Allow the pump to \ncool naturally. Do not touch or open it until temperature falls to a safe level \n(typically below 40\u202f°C on the surface). Use fans or ventilation to dissipate heat if in \nan enclosed space, but do not apply cold water on hot casings (risk of cracking). \n7. Fire Watch: If any smoke or fire was observed, have a fire extinguisher on hand and \na fire watch in place. Overheated oil or insulation could ignite. Confirm no fire risk \nbefore proceeding. \n8. Hazard Assessment: Before troubleshooting, perform a hazard assessment of the \narea[13]. Ensure no slip hazards (e.g. oil that may have leaked – clean it up), verify \nadequate lighting, and confirm that any adjacent equipment is stable. \nDo NOT proceed with further investigation or disassembly until the pump is fully isolated, \nlocked out, depressurized, and cooled. Once these immediate safety measures are in \nplace, troubleshooting can begin. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ee438062-562a-48f8-ad4b-f478125fc86a', embedding=None, metadata={'page_label': '4', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text=' \nBefore troubleshooting, ensure the pump is fully isolated and all safety protocols are \nfollowed. Lock out the power and valves, and wear appropriate PPE while the equipment \ncools. Trained technicians must verify zero energy (electrical and pressure) prior to hands-\non inspection[10][12]. \nStep-by-Step Troubleshooting Procedure \nFollow this systematic procedure to identify the cause of the overheating and correct it. All \nsteps should be logged in the work order or maintenance log, including measurements and \nfindings at each stage. \n1. Verify Overheat Condition: Confirm that the pump indeed experienced overheating \nand it’s not a false alarm. Check the bearing temperature gauges or electronic \nreadings for P-201 in the control system. Use an infrared thermometer to \nindependently measure the bearing housing and pump casing temperature[14]. \nNote the highest temperature observed and compare with allowable limits (e.g., \n>85\u202f°C which is above normal alarm)[2]. Also verify if any sensor malfunction could \nbe a factor (e.g., a faulty temperature sensor giving false reading[15]). If possible, \ninspect the temperature element wiring and calibration dates. \n2. Review Operating Status: Determine how the pump was operating at the time of \noverheating. Gather data from the DCS or pump log: flow rate, discharge pressure, \nsuction pressure, motor amps, and any recent transients. An overheating event \ncan be exacerbated by operation outside normal range – for example, running the \npump at very low flow (dead-heading) or below minimum flow can cause the \npump to overheat due to internal fluid friction[5]. Conversely, running at excessive \nflow (overload) can overheat the motor and bearings[16]. Note if the pump was in \nrecirculation mode, or if the minimum flow recirc valve was stuck closed. If the \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='15a3aef0-8120-4bc2-baf6-3e491ddf728b', embedding=None, metadata={'page_label': '5', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='feedwater tank (deaerator) level or pressure was abnormal (causing suction issues), \nrecord that as well. \n3. Switch to Standby (if available): If not already done, start the standby feed pump \n(P-202 if installed) to take over feedwater supply. Transfer the boiler feedwater load \ngradually to the standby pump. Once the standby is up to speed and carrying load, \nshut down the overheated pump (if it hasn’t tripped already). This ensures you can \ntroubleshoot without impacting unit operation. Note: Always adhere to changeover \nprocedures – open the discharge of standby pump, close the discharge of P-201 \nafter current equalization, etc., to avoid water hammer or loss of feed. \n4. Isolation and Drain (re-check): Re-verify that Pump P-201 is electrically and \nhydraulically isolated per the Immediate Safety Actions section. Double-check \nthat tags are in place and that there is no residual pressure. Open the pump casing \nvent valve at the top to ensure no pressure builds up due to residual heat. Open a \ndrain valve at the bottom of the pump casing to collect a sample of fluid (caution: it \nmay still be hot water). This fluid sample can be checked for signs of overheating \n(e.g., if water flashed to steam or any oil presence due to seal leak). Then close \ndrains/vents once pressure is relieved. \n5. External Visual Inspection: Perform a thorough external check of the pump \nassembly: \n6. Lubrication Oil Level: Look at the sight glass on the bearing oil reservoir. The oil \nlevel should be at the marked midpoint. If it’s low or empty, that’s a major cause of \noverheating (inadequate lubrication)[17]. Top up the oil to proper level only after \ncooling, and investigate any oil leakage that caused the loss[17]. \n7. Lubrication Oil Condition: Observe oil color through the sight glass or dipstick. \nDark, blackened, or cloudy oil indicates thermal breakdown or contamination. \nSmell the oil – a burnt odor means it has likely overheated and lost lubricity[8]. Plan \nto drain and replace degraded oil after internal inspection. \n8. Cooling Water Lines: Check the bearing oil cooler or cooling jacket lines. Ensure \nthe cooling water supply valve is open and water is flowing. Carefully touch (or use \nIR) on the inlet vs. outlet piping of the oil cooler – a significant temperature \ndifference should be felt if cooling is working. Little to no difference could mean a \nblocked cooler or no flow[18]. Look for any closed valves or clogged strainers in \nthe cooling circuit and open/clean them as needed[18]. \n9. Pump and Motor Coupling: Inspect the coupling for signs of misalignment or \ndamage. Look for rubber element debris (if a flexible coupling), cracked coupling \nbolts, or shifted coupling hubs. Any misalignment can cause excessive bearing \nloading and heat[19]. If the coupling guard is removed, check alignment with a \nstraightedge initially; final alignment will be measured later. \n10. General Area: Check for any oil sprayed around (could indicate a high-pressure oil \nleak from a seal or gasket). Notice any discoloration on the pump casing or motor \n(bluing of metal can indicate overheating). Also verify if the pump’s mechanical ...
#  Document(id_='983b2011-ae86-457d-ab5b-50ba34bb0bd5', embedding=None, metadata={'page_label': '6', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='11. Check Bearing Lubrication System: If Pump P-201 has an external lube oil system \n(oil pump, filters, cooler), inspect it in detail: \n12. Oil Pump & Pressure: Ensure the lube oil pump (if applicable, sometimes shaft-\ndriven or electric auxiliary pump) is operational. Check the lube oil pressure gauge; \na low reading might indicate the pump failed or a clogged filter. Normal lube oil \npressure should be as per OEM spec (e.g., ~2–3 bar). If zero, that explains the \noverheating (no oil flow). \n13. Oil Filters: Isolate and open the oil filter housing (after ensuring no pressure) to see \nif it’s clogged. A clogged filter can starve bearings of oil. Replace or clean filters as \nneeded. \n14. Oil Cooler: If not already, open any bypass valves and flush the oil cooler. Remove \ncooler end-caps (if design allows) to inspect for scaling or blockage. Clean the \ncooler tubes. Restore cooling water flow and verify no blockage. \n15. After any interventions, refill oil to the correct level with the proper grade (use OEM-\nspecified oil, e.g. ISO VG46 turbine oil). Do not reuse old overheated oil. \n16. Detailed Bearing Inspection: Once the pump is sufficiently cool, consider \ninspecting the bearings themselves: \n17. Remove the bearing housing covers (journal and thrust bearing housings). This may \nrequire unbolting and carefully lifting the covers. Examine the bearing surfaces for \ndiscoloration (a dark brown or black streak indicates overheating), wiping, or metal \nsmear. Overheated babbitt bearings may show babbitt melting or wiping. Rolling-\nelement bearings may show blueing of races or rollers if overheated. If such \ndamage is present, the bearings will need replacement. \n18. Check bearing clearances (with a feeler gauge or by shaft lift test) if possible, to see \nif they are within spec. Overheating can either cause clearance to tighten (thermal \nexpansion) or excessive wear (increasing clearance). \n19. Collect an oil sample (if not already) and consider sending it for analysis – high \nmetal content or varnish would confirm internal wear and overheating[20]. \n20. Shaft and Rotor: Try to rotate the pump shaft by hand (with coupling disconnected, \nusing a turning wrench). It should turn smoothly. Any binding or rubbing sensation \ncould indicate internal contact (e.g., between impeller and casing or wear rings). If \ninternal rubbing is suspected due to thermal expansion, note that as a possible \ncause[21]. \n21. Internal Pump Inspection (if required): If external and bearing inspections have \nnot identified a clear cause, you may need to open the pump casing for internal \ninspection (this is a more involved process requiring pump outage and new \ngaskets/seals): \n22. Drain the pump completely. Unbolt the appropriate casing sections as per the \npump’s maintenance manual (multistage pumps often have through-bolts and \ncasing split rings). \n23. Inspect impellers and diffusers for signs of cavitation (pitted surfaces) or rubbing \n(shiny contact marks where clearance should exist). Cavitation is a common cause ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_templat ...
#  Document(id_='8823ef1c-933a-43ae-8ca9-6710f9f1cdd8', embedding=None, metadata={'page_label': '7', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='of overheating and damage – it occurs if NPSH available is too low, causing vapor \nbubbles that collapse and generate heat[22][23]. If you find cavitation damage, \nlikely the pump was starved of NPSH or run at too high temperature on suction. \n24. Check wear ring clearances and balance drum (if any) for tight spots or scoring. \nThermal distortion can cause internal parts to rub. \n25. Look for any foreign object or debris in the pump that could have partially blocked \nflow (though unlikely in feedwater line with strainers, but worth a check). A partially \nblocked suction strainer can cause both cavitation and reduced flow, leading to \noverheating[23]. \n26. After inspection, if damage is found (e.g., impeller wear, seized bearing, etc.), plan \nfor repair or replacement of those parts. Document all findings with photos if \npossible. \n27. Check Alignment & Drive Train: Using precision tools, measure the pump-motor \nalignment. Employ a dial indicator or laser alignment tool on the coupling. Check \nboth offset and angular alignment. Misalignment beyond tolerance (typically \n>0.05 mm for high-speed machinery) can cause bearing stress and overheating[19]. \nIf misaligned, schedule a proper alignment of the motor to pump before restart. \nAlso inspect the baseplate, grouting, and hold-down bolts – a loose foundation can \nlead to vibration and misalignment over time. Tighten any loose bolts (coupling or \nbase). \n28. Review System Conditions: Concurrently, evaluate if systemic issues \ncontributed: Was the feedwater temperature unusually high (e.g., deaerator \nmalfunction leading to higher-than-design suction temp)? High suction temperature \ncan reduce cooling margin and contribute to pump overheating[24]. Ensure the \ndearator is operating at the correct pressure and temperature. Check if the pump \nwas operating continuously without rotation – continuous operation without regular \nswap can accumulate heat (pumps are often alternated to allow cooling)[25]. If no \nrotation schedule was in place, this might be a contributing factor. \n29. Determine Root Cause: Summarize the findings from steps 5–10. Likely root \ncauses of the overheating should become clear. Common findings might include: \nlow oil level, oil cooler blockage, failed bearing, misalignment, cavitation due to \nsuction issues, or running the pump outside its recommended range. It’s possible \nmultiple factors coincided. Identify all that apply. For each root cause identified, \nplan the corrective action (see Root Cause Diagnostics below for typical \ncauses/remedies). If any cause is still not clear, consider consulting the pump OEM \nor a specialist, especially if internal damage is puzzling. \n30. Corrective Actions: Implement repairs and corrections based on the root cause: \no Replace damaged bearings with new ones (or an entire bearing cartridge if \napplicable). Ensure new bearings are installed per OEM procedure, with \nproper clearances and lubrication. \no Fix the lubrication issues: repair leaks, refill with correct oil, replace filters, \nand ensure the cooling system is functional (open valves, clean coolers). \nAfter refilling oil, vent the oil system of  ...
#  Document(id_='79605aff-7691-4924-8625-f5e5a1719fdc', embedding=None, metadata={'page_label': '8', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='o If misalignment was found, re-align the pump and motor. Use laser \nalignment tools for precision and secure all mounting bolts afterward. \no For cavitation issues, address the upstream cause: ensure suction strainers \nare clean, the dearator pressure/level are stable, and check that any \nminimum flow recirculation valve is operating so the pump never runs at \n<30% design flow[5]. If the recirculation system was faulty (e.g., a closed \nminimum flow valve), repair or adjust it. \no Replace any worn internal parts (impellers, wear rings, mechanical seal, \netc.) as needed before reassembly. \no Documentation: Document all parts replaced and adjustments made. If the \npump required major overhaul, note it in the equipment history. Also \ndocument the cause for future reference (e.g., “Oil cooler 70% blocked with \nscale – cleaned” or “Found bearing wiped due to oil starvation – replaced \nand fixed leak at seal”). \n31. Pre-Startup Check: Before restarting the pump, perform an inspection to verify all \nsteps are completed: All components are reassembled correctly, oil is at proper \nlevel, cooling water is flowing, coupling is reinstalled and aligned, all tools and rags \nare removed from the area, and all LOTO tags are still in place (we will remove \nthem right before restart). Fill out the inspection Checklist in the next section to \nensure nothing is missed. \n \nDuring troubleshooting, carefully inspect gauges, oil levels, and cooling lines for \nanomalies. Systematically check each potential cause of overheating – from lubrication to \nalignment – and record the findings[26][18]. In the image, a technician examines pump \npressure gauges as part of the diagnostic process. \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='56dd0691-2a6a-4b10-9a26-f8727c118ba4', embedding=None, metadata={'page_label': '9', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Root Cause Diagnostics \nBased on the troubleshooting findings, categorize the root cause of the overheating. \nCommon root causes for an overheated pump in a power plant and their diagnostic \nindicators include: \n• Inadequate Lubrication: Low oil level or poor oil quality leads to insufficient \nlubrication, causing bearing metal-to-metal contact and heat[17][27]. Indicators: \nLow sight-glass reading; burnt oil smell; bearing damage observed. Remedy: \nRestore oil to proper level, fix leaks, use correct oil grade, and replace bearings if \ndamaged. Implement regular oil level checks and scheduled oil changes. \n• Cooling System Failure: Blocked or reduced cooling flow to the oil cooler or \nbearing housing causes temperatures to rise[28]. Indicators: Little temperature \ndrop across cooler; fouling in cooling water passages; high oil temperature. \nRemedy: Clean/flush the oil cooler and cooling lines[18], ensure valves are open \nand water quality is good. Consider installing filters or water treatment if scaling is \nrecurrent. \n• Misalignment or Mechanical Friction: Misaligned pump and driver shafts cause \nextra load on bearings and seals, generating heat[19][29]. Internal rubbing (e.g., due \nto thermal expansion or misassembly) can also overheat the pump[21]. Indicators: \nCoupling wear patterns, high vibration, uneven bearing wear. Remedy: Realign the \npump and motor to within tolerance; verify proper thermal expansion procedures \n(warm up pump if needed, allow sliding foot if applicable). Ensure internal \nclearances and alignment pins are per OEM spec during reassembly. \n• Cavitation / Suction Issues: Cavitation occurs if Net Positive Suction Head \n(NPSH) available is too low or feedwater temperature is too high, causing vapor \nbubbles that collapse and generate local heat[7][22]. Also, low flow operation \n(pump running with discharge closed or <30% flow) causes continuous \nrecirculation of hot water inside the pump[5]. Both result in overheating of fluid and \npump. Indicators: Noise (gravel-like or popping sounds), pitted impeller surfaces, \npossibly oscillating discharge pressure. Remedy: Fix suction conditions – maintain \ndearator pressure/level, clean suction strainers[23], and ensure minimum flow line \nis functioning. Avoid operating pump below the minimum flow; if load is low, keep \nrecirculation open or use auto-recirculation valve. \n• Overloading / Operating Beyond Design: Pushing the pump beyond its design \npoint (excess flow or head) or running at full load continuously can overheat the \nmotor and bearings[16][30]. Indicators: Motor current above rated, motor casing \nvery hot, frequent over-current trips, or discharge pressure/flow higher than spec. \nRemedy: Throttle flow to keep pump within its performance curve. If process \ndemands have changed, consider a pump with proper sizing. Ensure safety devices \n(like thermal overloads and flow limiters) are set correctly. \n• Bearing Wear or Failure: A bearing nearing end-of-life (fatigued or contaminated) \ncan run hot even if lubrication is ok, due to increased friction. Indicator: Vibration ', path=None, url=None, mimetype=None), image_resource=None, audi ...
#  Document(id_='aad11b26-cdf3-4a05-b05a-e63cc4ff8423', embedding=None, metadata={'page_label': '10', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='trending upward over time, metal in oil sample, a wobbly shaft or unusual shaft \nmovement. Remedy: Replace bearings at scheduled intervals; investigate any \nbearing that fails prematurely for underlying cause (misalignment, contamination, \netc.). \n• Continuous Operation without Rest: Pump P-201 might have overheated simply \ndue to lack of rotation – running non-stop for extended periods can cause gradual \nheat soak, especially if its standby was never used[25]. Even if within design, \ncontinuous running can wear out oil and components. Remedy: Implement a pump \nrotation schedule (e.g., alternate pumps weekly or monthly)[25] so each pump can \ncool down and undergo maintenance. Ensure oil is changed at recommended \nintervals to avoid degradation. \n• External Environmental Factors: Less common in a controlled power plant \nenvironment, but high ambient temperature or poor ventilation around the pump \ncan impede heat dissipation[31]. For example, if the pump room ventilation failed, \nheat could accumulate. Also, check for any external heat sources near the pump. \nRemedy: Restore room ventilation fans, remove any heat barriers around pump, \nand in extreme cases consider adding a fan or cooling unit for the pump area. \n• Instrumentation Issues: In some cases, the “overheating” might have been a false \nreading from a bad sensor. If no evidence of actual overheating is found, suspect \nthe instrumentation. Remedy: Calibrate or replace faulty temperature sensors, and \nverify the trip settings. \nEach cause above may contribute to the overheating. It’s crucial to address all \ncontributing factors, not just one. For instance, if misalignment and low oil were both \nfound, both issues must be resolved. Reference relevant OEM manuals for tolerance and \nrecommended practices for each fix. Document the root cause analysis in the report and \nupdate the preventive maintenance plan to avoid recurrence (e.g., schedule cooler \ncleaning, alignment checks, etc.). \nSupporting Info: Overheating in pumps is often multifactorial. Industry guidelines (e.g., \nNFPA 20 for fire pumps) note that bearing temps beyond ~82–104 °C are unsafe[2]. Main \ncauses identified in industry case studies include lubrication failures, blocked cooling \npathways, rotor misalignment, cavitation from suction issues, and overloading \nconditions[32] – all of which have been considered in the above analysis. \nInspection Checklist – Overheated Pump P-201 \nAfter completing repairs or adjustments, use the following inspection checklist to ensure \nall necessary items have been addressed and the pump is ready for a safe restart. Each \ncheckpoint should be reviewed and marked off by the responsible engineer or technician: \nInspection Item Acceptable Condition / Criteria \nStatus \n(✔/✘) Remarks \nLOTO Verification All energy sources isolated  e.g., Breaker ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='49ec35eb-dc77-4be5-ab42-1abcb438786a', embedding=None, metadata={'page_label': '11', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Inspection Item Acceptable Condition / Criteria \nStatus \n(✔/✘) Remarks \n(electrical, hydraulic). tagged, valves \nlocked. \nPump Casing Cool Casing temperature < 40\u202f°C (safe to \ntouch). \n (Use IR gun to \nconfirm). \nOil Level (Bearing \nHousing) \nOil at midpoint of sight glass; no \nvisible leaks[17]. \n (Refilled with ___ \noil grade). \nOil Condition Clean, amber color; no burnt smell \nor turbidity. \n (Oil changed on \nmm/dd/yy). \nOil Pressure (if \napplicable) \n> 2 bar during priming (when pump \nrunning). \n (Measured ___ bar \nat idle). \nCooling Water \nFlow \nCooling water valves open; cooler \ninlet vs outlet warm/cool to \ntouch[18]. \n (Inlet °C / Outlet \n°C). \nBearing \nTemperature \nNormal range 50–70\u202f°C during \noperation[3]; Alarm set ~85\u202f°C. \n (Verify sensor \nreading). \nBearing \nReplacement \nBearings inspected/replaced if \nneeded; clearances OK. \n (New DE/NDE \nbearings \ninstalled?). \nCoupling \nAlignment \nAlignment within 0.05 mm (shim \nadjusted as needed)[19]. \n (Laser alignment \nreport attached). \nCoupling Hardware Coupling bolts tight; elastomer \nelements in good condition. \n (Replaced spider \nelement). \nInternal Inspection Impellers, wear rings, seal in good \ncondition (no rubbing/cavitation \ndamage). \n (Impeller #3 \nreplaced? Y/N). \nSuction Strainer Strainer/basket clean; no debris or \nblockage[23]. \n (Cleaned on \nmm/dd/yy). \nMechanical Seal Seal not leaking; flush/quench lines \n(if any) flowing. \n (Seal replaced? \nY/N). \nBolting & Supports All pump and base bolts torqued; \nsupport clamps secure. \n (Baseplate grout \nintact). \nInstrumentation Temp and vibration sensors \ncalibrated; alarm/trip setpoints \nverified. \n (Calibrated on \nmm/dd/yy). \nStandby \nEquipment \nStandby pump in auto or ready; no \nissues after swap. \n (P-202 returned to \nstandby). \nDocumentation Work order updated; cause and fix  (Report # filed in ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='e881e2c2-d6f1-4fcc-a7f3-85cfa626333b', embedding=None, metadata={'page_label': '12', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Inspection Item Acceptable Condition / Criteria \nStatus \n(✔/✘) Remarks \ndocumented; crew sign-off done. CMMS). \nInstructions: For each item, enter a check ✔ if okay or ✘ if not, and add any remarks or \ncorrective actions taken. All items must be ✔ (acceptable) before removing LOTO and \nrestarting Pump P-201. \nRestart Procedure After Repair \nOnce the pump has been inspected and all issues rectified, follow this controlled restart \nprocedure to safely return Pump P-201 to service: \n1. Pre-Start Briefing: Conduct a brief with Operations and Maintenance personnel. \nReview the work done and ensure everyone is aware of the restart plan. Confirm \nthat it’s safe to restart and all team members are clear of the pump area. \n2. Remove Lockouts/Tagouts: The responsible person (maintenance lead) should \nremove the LOTO devices in coordination with the Control Room. Restore power \nsupply to the motor (close breaker) only when instructed, and crack open (partially \nopen) the suction and discharge isolation valves. Ensure the discharge valve is \ninitially mostly closed – do not start the pump on a wide-open discharge valve[33], \nas this can cause a sudden load and “jerk” the system. \n3. Prime and Vent: If the pump was drained or opened, ensure it is fully refilled with \nwater (prime the pump). Open the vent valve on top of the pump casing and fill the \npump either by gravity from the dearator or using a manual filling pump until water \ncomes out of the vent without air. Close the vent. Verify suction valve is fully open \nand suction pressure is normal (deaerator pressure stable). \n4. Cooling & Lube Startup: Start any auxiliary systems first: turn on the cooling water \nflow to the bearings/oil cooler and the lube oil pump (if a separate lube pump exists) \nto establish lubrication before the main pump starts. Verify oil pressure is in range \nand cooling water is flowing. \n5. Bump Check (Rotation): Engage the motor briefly (bump start) to verify the rotation \ndirection is correct (especially if motor leads were disconnected during work). The \npump should rotate in the correct direction (check arrow on casing). Also listen for \nany unusual sounds on this bump. Then stop. If rotation is correct and no \nimmediate issues, proceed. \n6. Start Pump: Start the pump either locally or from the control room per standard \noperating procedures. The pump will come up to speed (for motor-driven, this is \nquick; for steam turbine-driven, follow the warm-up and rolling procedure as \napplicable). Monitor the pump closely during startup. Keep the discharge valve \n~5–10% open initially to allow a minimum flow out (prevent dead-head) but still \nimpose backpressure so the pump isn’t at full load instantly. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4f4a2b3f-63e3-4c29-acc5-7e04379d02f7', embedding=None, metadata={'page_label': '13', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='7. Gradually Load Pump: Once at full speed and stable, slowly open the discharge \nvalve to allow the pump to ramp up to the desired flow/pressure. Do this in \ncoordination with the control room to smoothly transfer feedwater flow from the \nstandby pump (if applicable) or to meet boiler demand. Avoid any rapid flow \nchanges to prevent water hammer. \n8. Monitor Conditions: As the pump reaches normal operating conditions, closely \nmonitor all parameters: bearing temperatures, oil pressure, cooling water \ntemperatures, pump discharge pressure/flow, motor amps, and vibration readings. \nInitially, check bearing temperature every 5 minutes; it should rise slowly and \nstabilize within normal range (e.g., if it was 25\u202f°C ambient, it might stabilize around \n60\u202f°C)[3]. Vibration should remain below alarm (typically <5 mm/s). Listen for any \nabnormal noise (no rattling or grinding should be present). \n9. Leak Check: Inspect all around the pump for leaks as it runs: look at mechanical \nseal (should be no excessive dripping, slight weep could be normal if it’s a packed \ngland), check all flanges and drains. Tighten any packing gland slightly if needed (if \nit’s packing type seal) to stop a steady drip – but do not over-tighten. \n10. Normal Operation: When the pump is fully on-line and stable, notify the control \nroom. The pump can now carry the feedwater load. If this pump was a standby now \nreplacing a failed pump, ensure the system is adjusted accordingly. If both pumps \nwill run in parallel for a time, coordinate their outputs to desired levels. \n11. Post-Start Monitoring: For at least the first hour of operation, have maintenance \npersonnel periodically (every 15 minutes) check the pump’s temperature and other \nvital signs. Ensure the bearing temperature stays well below alarm. Any trending \nupward could indicate an unresolved issue – be prepared to take action if \nsomething isn’t right. \n12. Remove Temporary Controls: Remove any tags or signs that were placed around \nthe pump area indicating it was under maintenance once fully satisfied the pump is \nrunning okay. (However, do keep any “Caution Hot” signs if surfaces are still above \n50\u202f°C). \n13. Documentation and Handover: Formally hand over the pump to Operations. \nDocument the restart date/time and the conditions in the maintenance log. Also \nschedule a follow-up inspection after 24 hours of runtime to re-check bolt \ntightness, oil level, etc. Finally, close the work order with detailed notes on the \ncause and fix. If any Management of Change (MOC) or engineering follow-up is \nrequired (e.g., updating a procedure or design change like adding a bearing \ntemperature sensor), note that for action. \nReminder: Never start or stop the pump with the discharge valve fully open, to avoid water \nhammer and mechanical stress[33]. Starting against a closed (or slightly open) discharge \nensures a smoother ramp-up and prevents sudden jerk loads on the pump and driver, \nwhich can damage bearings and internal components[33]. Always follow the OEM start-up \nguidelines specific to Pump P-201. ', path=None, url=None, mimetype=None), image_resource=None, audio_reso ...
#  Document(id_='38d811db-565b-45ef-a716-7c5b3978ef35', embedding=None, metadata={'page_label': '14', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='Common Causes and Historical Notes \nOverheating issues with Pump P-201 have occurred in the past. Understanding these \nhistorical cases can help prevent future recurrences. Below are some common causes of \npast overheating incidents and notes from our plant’s history: \n• June 2024 Incident: Pump P-201 tripped on high bearing temperature. Investigation \nfound the lube oil cooler was partially blocked with sediment. Cooling water flow \nwas only ~50%. The reduced heat removal caused gradual temperature rise over a \nshift. The bearing metal temp reached 95\u202f°C triggering a trip. Action: The cooler was \nchemically cleaned and a cooling water filtration system was installed to prevent \nblockage. After this fix, normal bearing temps dropped to ~60\u202f°C under full load. \nThis incident reinforced the importance of regular cooler maintenance. \n• December 2024 Incident: After an overhaul, P-201 experienced overheating and \nhigh vibration on restart. It did not trip, but temperatures were ~10\u202f°C above normal \nand rising. We shut it down as a precaution. Root cause was misalignment – the \npump and motor were not precisely aligned during re-installation. This caused \nexcessive coupling strain and hot bearings. Action: Performed laser alignment \n(found angular misalignment of 0.3 mm at coupling). Post-alignment, the vibration \nand temperature returned to normal. Lesson learned: always perform and verify \nalignment after maintenance. \n• Continuous Operation Issue (General): It was noted in 2023 that Pump P-201 ran \nfor 14 months continuously without rotation, because the standby pump P-202 was \nout of service for overhaul. The extended run led to gradual oil degradation and a \nminor increase in bearing temperature over time. While no trip occurred, the \nbearing temps were ~5\u202f°C higher than when pumps are swapped regularly. Action: \nWe now adhere to a pump changeover schedule – swapping P-201 and P-202 \nmonthly[25]. This allows each pump to cool, and lets maintenance check oil and \ncomponents. Since implementing rotation, bearing temperatures have remained \nconsistently within range. \n• OEM Advisory (2025): The pump manufacturer (ABC Pumps Co.) issued a tech \nbulletin advising to check the minimum flow recirculation orifice for clogging. A \npartially clogged recirc line can reduce bypass flow at low loads, potentially causing \npump overheating due to low-flow operation. We inspected our recirculation line \nand found some scaling. Action: In the next outage, we plan to clean or replace the \nminimum flow orifice and add it to the maintenance checklist. \n• Common Causes Summary: Overall, our experience matches industry guidance: \nmost overheating cases trace back to cooling/lubrication issues, flow extremes, \nor mechanical setup problems[32][34]. By addressing oil quality, keeping cooling \nwater clean, operating within design parameters, and ensuring proper installation, \nwe have significantly reduced overheating occurrences. ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4ec3191e-ba16-4c37-b2e6-680a6b6bf4eb', embedding=None, metadata={'page_label': '15', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='These historical notes should be shared with new engineers and included in training. They \nhighlight why adhering to this SOP and performing regular preventative maintenance (oil \nchanges, cooler flushes, alignment checks, etc.) is critical. \nSafety and Compliance Reminders \nWorking on high-pressure, high-temperature feed pumps involves significant hazards. \nAlways keep these safety and compliance points in mind: \n• Lockout/Tagout: Never bypass or shortcut the LOTO process. Before maintenance, \nall energy sources must be isolated and locked/tagged[10]. Verify isolation each \ntime (try to start the motor with the breaker open to confirm zero energy). This is not \nonly plant policy but also an OSHA requirement for hazardous energy control. \n• Personal Safety: Wear appropriate PPE at all times and be aware of hot surfaces. \nUse insulated tools/gloves on parts that might be hot. If you must work near a \nrunning pump (for inspections), wear hearing protection and stay clear of rotating \nparts (ensure guards are in place). Do not wear loose clothing or jewelry that could \nget caught. \n• Pressure Hazard: Treat any pressurized section with caution. Even after shutdown, \nwait and open drains slowly, as hot water under pressure can cause violent flash \nsteam. Stand to the side of valves/flanges when cracking them open. Ensure relief \npaths are working (like thermal relief valves on isolated sections). \n• Environmental and Regulatory Compliance: Dispose of any waste oil, oily rags, \nused filters, and damaged parts according to environmental regulations. Document \nthe disposal per the plant’s waste management plan. Any release of feedwater or oil \nshould be reported and cleaned up to prevent slips or environmental harm. \n• Follow OEM Guidelines: This SOP complements the OEM manual – always cross-\nreference the pump manufacturer’s recommendations for limits and procedures. \nFor example, OEM may specify maximum casing heat-up rates, specific lubrication \ngrades, or unique restart steps. Ensure compliance with those to maintain warranty \nand integrity. \n• Recordkeeping: It’s crucial to log all maintenance activities in the Computerized \nMaintenance Management System (CMMS) or logbook. Accurate records support \nreliability analysis and compliance audits. Note the date, findings, parts replaced, \nclearances measured, and persons involved. Also log the bearing temperature \ntrends and vibration readings after the event for future reference. \n• Training and Authorization: Only qualified personnel should perform this \ntroubleshooting. Electrical work (isolating motor, etc.) must be done by authorized \nelectricians, and mechanical work by trained millwrights or engineers. Ensure \neveryone has read this SOP and related documents. Conduct drills or reviews of \npump trip response periodically. \n• Compliance Standards: Adhere to relevant standards such as OSHA 1910 for \ngeneral industry safety, and any power industry regulations. For example, NFPA ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='8eae9766-eed2-4278-8a00-a87010b5fa5e', embedding=None, metadata={'page_label': '16', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='standards may not directly apply to feed pumps (they apply to fire pumps), but their \nguidelines on temperature limits can be a helpful reference[2]. Company \nengineering standards for rotating equipment should be followed. If an incident \noccurs, it may need to be reported as per regulatory requirements (e.g., if there was \na reportable release or if safety interlocks failed). Always aim for not just \ncompliance but a safety-first culture. \nBy keeping safety at the forefront and following this procedure, maintenance staff can \ntroubleshoot and restore the pump without incident, and ensure reliable and safe \noperation in the power plant. \nAppendix \nA. Instrumentation Alarm/Trip Setpoints (Pump P-201) \n(For reference – actual setpoints as per Instrumentation Dept.) \nParameter High Alarm \nHigh-High \nTrip Notes \nPump Bearing \nMetal Temperature \n85\u202f°C \n(alarm) \n95\u202f°C (trip) Normal ~50–70\u202f°C[3]. Trip based on \nOEM limit ~100\u202f°C[2]. \nLube Oil \nTemperature \n(outlet) \n60\u202f°C 70\u202f°C At oil cooler outlet. High temp may \nindicate cooling issues. \nLube Oil Pressure 1.5 bar (low \nalarm) \n1.0 bar (low \ntrip) \nMeasured at bearing header. Trips \npump on loss of oil pressure. \nPump Casing Drain \nTemperature \n120\u202f°C \n(alarm) \n– (no trip) (If > alarm, indicates possible flash or \nlow flow heating). \nPump Vibration \n(Overall) \n8 mm/s \nRMS \n(alarm) \n12 mm/s \nRMS (trip) \nPer ISO 10816 for this class of \nmachine. \nMotor Winding \nTemperature \n130\u202f°C \n(alarm) \n140\u202f°C (trip) Motor thermal limit (if motor-driven). \nMotor Bearing \nTemperature \n90\u202f°C \n(alarm) \n100\u202f°C (trip) Motor has its own bearings; similar \nlimits as pump. \nSuction Pressure 0.3 MPa \n(low alarm) \n– Low suction can cause cavitation \nalarm. (No trip, but an interlock may \nprevent start if too low). \nDischarge Pressure 14 MPa (low \nalarm) \n16.5 MPa \n(high alarm) \nAlarm if outside normal range \n(indicative of off-curves operation). \nNote: These setpoints are configured in the plant DCS for Pump P-201. Alarm alerts \noperators to take action, Trip will automatically shut down the pump to protect it. Values ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='ea0b2d02-370c-4e4d-9290-d74cf3429bf9', embedding=None, metadata={'page_label': '17', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='are based on manufacturer’s recommendations and industry practices (bearing temps per \nOEM, aligned with NFPA 20 guidance of ~82–104\u202f°C max[2]). Always refer to the latest \ninstrument datasheets for any updates to these values. \nB. Contact Information \nFor further assistance or to report an incident involving Pump P-201, use the following \ncontact list: \n• Maintenance Lead – Mechanical: John Doe – Phone: +971-55-123-4567, Email: \njohn.doe@sunrisepower.ae \n• Operations Shift Supervisor (Unit 3): Maryam Al Mansoori – Radio: Channel 3, \nPhone: +971-55-234-5678 \n• Instrumentation Engineer: Ahmed Rahim – Ext: 4431, Email: \nahmed.rahim@sunrisepower.ae \n• Maintenance Manager: Li Wei – Ext: 4400, Office: Bldg 5 Room 12 \n• Safety Officer: Priya Patel – Ext: 4015, to be notified in case of any safety incident or \nif permit conditions need review. \n• Pump OEM Support (ABC Pumps Co.): 24/7 Hotline: +1-800-ABC-PUMP (have \npump serial number ready when calling). Local Rep: Gopal Srinivasan – Email: \ngopal.srinivasan@abc-co.com. \nKeep this contact list posted in the control room and maintenance workshop. In an \nemergency (e.g., fire, severe injury), always call the main emergency number (Dial 999 \nfrom plant phone or as per site protocol) before contacting individuals. \n \nRevision History: \n- Rev. 1.0 – 15/12/2025: Initial issue of troubleshooting guide for overheated pump P-201 \n(Author: J. Smith). Approved by Plant Manager A. Khan. \n- Rev. 0.0 – 01/12/2025: Draft created and reviewed by Maintenance and Operations (not \nreleased). \nReferences & Related Documents: \n- Pump P-201 OEM Manual – ABC Pumps Document #BF-P201-O&M, Rev. 2019. \n- Plant Maintenance Procedure ENG-MECH-012: “Rotating Equipment Alignment \nStandard”. \n- HSE Procedure HSE-LOTO-001: “Lockout/Tagout – Control of Hazardous Energy”. \n- Incident Report IR-2024-06: “Investigation of P-201 Overheating on 01-June-2024”. \n- [35]91FirePump – “How to Handle Fire Pump Overheating Problems”, Sec.1, 2025 – for \ngeneral temperature guidelines and causes. \n- [36][37]PowerPlantCalculations – “Boiler Feed Pump Troubleshooting Guide”, 2025 – on \nhigh bearing temperature causes (low oil, cooling). \n- [34][5]PowerPlantCalculations – “BFP Pump Overheating Causes”, 2025 – guidance on ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='28d69db1-3307-4f03-bccb-831b1b38af1e', embedding=None, metadata={'page_label': '18', 'file_name': 'SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_path': '/content/data/SOP_ Troubleshooting Overheated Boiler Feed Pump (Pump P-201).pdf', 'file_type': 'application/pdf', 'file_size': 474758, 'creation_date': '2025-12-15', 'last_modified_date': '2025-12-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='operation at low flow and high flow affecting pump temperature. \n- [38]EmpoweringPumps – “Bearings Run Hot – Troubleshooting”, 2020 – on misalignment \nand lubrication checks for hot bearings. \n- [10][12]MPO Cincinnati – “Industrial Pump Maintenance Checklist”, 2025 – Pre-\nmaintenance safety (LOTO, PPE). \n(End of SOP) \n \n[1] [4] [6] [16] [31] Troubleshooting Guide: How to Prevent A Pump Overheating? \nhttps://www.streampumps.com/product-qa/pump-overheating-240604.html \n[2] [7] [8] [9] [14] [20] [22] [27] [28] [29] [30] [32] [35] How to Handle Fire Pump Overheating \nProblems  \nhttps://www.91firepump.com/media/industry-news/how-to-handle-fire-pump-\noverheating-problems.html \n[3] [5] [15] [17] [18] [21] [23] [24] [25] [33] [34] [36] [37] Power plant and calculations: 12-\ntroubleshooting guide for Boiler Feed Pumps (BFP) \nhttps://www.powerplantandcalculations.com/2025/03/12-troubleshooting-guide-for-\nBoiler-feed-pumps-BFP.html \n[10] [11] [12] [13] Industrial Pump Maintenance Checklist (Free PDF Download) \nhttps://www.mpofcinci.com/blog/industrial-pump-maintenance-checklist/ \n[19] [26] [38] Centrifugal Pump Minute-Troubleshooting: Bearings Run Hot - Empowering \nPumps and Equipment \nhttps://empoweringpumps.com/psg-centrifugal-pump-minute-troubleshooting-bearings-\nrun-hot/ ', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]
